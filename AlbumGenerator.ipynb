# %%
import os
import tkinter, tkinter.filedialog#[開く]で元画像フォルダー選択するために必要なライブラリ
from PIL import Image, ImageDraw, ImageFilter#画像処理に必要なライブラリ
from PIL import Image, ImageDraw, ImageFont#画像に文字を入れるために必要なライブラリ

cov_base_tate = Image.open('base_tate.jpg')#表紙の下地画像を呼び出し
cov_base_yoko = Image.open('base_yoko.jpg')#表紙の下地画像を呼び出し


text0 = Image.open('text0.jpg')#文字画像を呼び出し
text1 = Image.open('text1.jpg')#文字画像を呼び出し
text2 = Image.open('text2.jpg')#文字画像を呼び出し
rotare_text2 = text2.rotate(90, expand=True)

base = Image.new('RGB', (5043, 2551), 'white')#下地の白画像をbaseという名前で生成


#表紙元画像フォルダー選択
root = tkinter.Tk()
root.withdraw()
msg = '表紙の画像フォルダーを選択してください。'
cover_img_dir_path = tkinter.filedialog.askdirectory(title=msg)
if (not cover_img_dir_path): #[キャンセル]クリック時の処理
    print('フォルダーを選んでください。')
    sys.exit()
#表紙元画像フォルダー選択ここまで

#元画像フォルダー選択
msg = '中身の画像フォルダーを選択してください。'
img_dir_path = tkinter.filedialog.askdirectory(title=msg)
if (not img_dir_path): #[キャンセル]クリック時の処理
    print('フォルダーを選んでください。')
    sys.exit()
#元画像フォルダー選択ここまで

#出力先フォルダー選択    
msg = '出力先フォルダーを選択してください。'    
output_dir_path = tkinter.filedialog.askdirectory(title=msg)    
if (not output_dir_path):#[キャンセル]クリック時の処理    
    print('フォルダーを選んでください。')
    sys.exit()
#出力先フォルダー選択ここまで

#表紙のディレクトリ
print("表紙："+ cover_img_dir_path)
cover_directory = os.listdir(cover_img_dir_path)
cover_directory.remove('.DS_Store')#Mac用

#表紙以外の写真をリスト化
print("中身："+ img_dir_path)

directory = os.listdir(img_dir_path)
directory.remove('.DS_Store')#Mac用
sorted_directory = sorted(directory )
print(sorted_directory)

print("出力先："+ output_dir_path)

cov = Image.open(os.path.join(cover_img_dir_path,cover_directory[0]))#"cover/xxxxxxx_00x.jpg"を開く
cov_width, cov_height = cov.size


im0 = Image.open(os.path.join(img_dir_path,sorted_directory[0]))
im0_width, im0_height = im0.size


im1 = Image.open(os.path.join(img_dir_path,sorted_directory[1]))
im1_width, im1_height = im1.size

im2 = Image.open(os.path.join(img_dir_path,sorted_directory[2]))
im2_width, im2_height = im2.size

im3 = Image.open(os.path.join(img_dir_path,sorted_directory[3]))
im3_width, im3_height = im3.size

im4 = Image.open(os.path.join(img_dir_path,sorted_directory[4]))
im4_width, im4_height = im4.size

im5 = Image.open(os.path.join(img_dir_path,sorted_directory[5]))
im5_width, im5_height = im5.size

im6 = Image.open(os.path.join(img_dir_path,sorted_directory[6]))
im6_width, im6_height = im6.size

im7 = Image.open(os.path.join(img_dir_path,sorted_directory[7]))
im7_width, im7_height = im7.size

im8 = Image.open(os.path.join(img_dir_path,sorted_directory[8]))
im8_width, im8_height = im8.size

im9 = Image.open(os.path.join(img_dir_path,sorted_directory[9]))
im9_width, im9_height = im9.size

im10 = Image.open(os.path.join(img_dir_path,sorted_directory[10]))
im10_width, im10_height = im10.size

im11 = Image.open(os.path.join(img_dir_path,sorted_directory[11]))
im11_width, im11_height = im11.size

im12 = Image.open(os.path.join(img_dir_path,sorted_directory[12]))
im12_width, im12_height = im12.size

im13 = Image.open(os.path.join(img_dir_path,sorted_directory[13]))
im13_width, im13_height = im13.size


#表紙
back_im = base.copy()#共通
back_im_tate = cov_base_tate.copy()
back_im_yoko = cov_base_yoko.copy()
resize_cov = cov.resize((int(cov_width * 0.73), int(cov_height * 0.73)))#

if cov_width < cov_height:
    back_im_tate.paste(resize_cov, (4975, 325))#縦
    back_im_tate.save(os.path.join(output_dir_path, "cover.jpg"), quality=100, dpi=(400, 400))
else:
    back_im_yoko.paste(resize_cov, (4025, 1140))#横
    back_im_yoko.save(os.path.join(output_dir_path, "cover.jpg"), quality=100, dpi=(400, 400))
#表紙ここまで       
    
#1-2ページ目
back_im = base.copy()#共通
resize_im0 = im0.resize((int(im0_width * 0.60), int(im0_height * 0.60)))#
if im0_width < im0_height:
    back_im.paste(resize_im0, (2985, 50))#縦   
else:
    back_im.paste(resize_im0, (2520, 475))#横
    
back_im.save(os.path.join(output_dir_path, "0001.jpg"), quality=100, dpi=(300, 300))
#1-2ページ目ここまで



#3-4ページ目
back_im = base.copy()#共通
resize_im1 = im1.resize((int(im1_width * 0.6), int(im1_height * 0.6)))
back_im.paste(resize_im1, (1250-int(im1_width*0.6/2), 1275-int(im1_height*0.6/2)))#左ページの中央にペースト 

resize_im2 = im2.resize((int(im2_width * 0.6), int(im2_height * 0.6)))
back_im.paste(resize_im2, (3800-int(im2_width*0.6/2), 1275-int(im2_height*0.6/2)))#右ページの中央にペースト 

back_im.save(os.path.join(output_dir_path, "0203.jpg"), quality=100, dpi=(300, 300))
#3-4ページ目ここまで


#５-６ページ目
back_im = base.copy()#共通
if im3_width < im3_height:#縦  
    resize_im3 = im3.resize((int(im3_width * 0.55), int(im3_height * 0.55)))
    back_im.paste(resize_im3, (1030-int(im3_width*0.55/2), 1275-int(im3_height*0.55/2)))#左ページの中央少し左寄りにペースト 
    back_im.paste(text0, (1790, 1100))#縦文字の挿入
     
else:#横
    resize_im3 = im3.resize((int(im3_width * 0.55), int(im3_height * 0.55)))
    back_im.paste(resize_im3, (1200-int(im3_width*0.55/2), 1145-int(im3_height*0.55/2)))#左ページの中央少し上寄りにペースト 
    back_im.paste(text1, (1410, 1930))#横文字の挿入
    
resize_im4 = im4.resize((int(im4_width * 0.6), int(im4_height * 0.6)))
back_im.paste(resize_im4, (3870-int(im4_width*0.6/2), 1275-int(im4_height*0.6/2)))#右ページの中央にペースト 

back_im.save(os.path.join(output_dir_path, "0405.jpg"), quality=100, dpi=(300, 300))
#５-６ページ目ここまで


#7-8ページ目
back_im = base.copy()#共通
if im5_width < im5_height:#縦  
    resize_im5 = im5.resize((int(im5_width * 0.625), int(im5_height * 0.625)))
    back_im.paste(resize_im5, (1250-int(im5_width*0.625/2), 0))#左ページの中央にペースト 
else:#横
    resize_im5 = im5.resize((int(im5_width * 0.55), int(im5_height * 0.55)))
    back_im.paste(resize_im5, (1200-int(im5_width*0.55/2), 1275-int(im5_height*0.55/2)))#左ページの中央にペースト 

if im6_width < im6_height:#縦  
    resize_im6 = im6.resize((int(im6_width * 0.625), int(im6_height * 0.625)))
    back_im.paste(resize_im6, (3870-int(im6_width*0.625/2), 0))#右ページの中央にペースト 
else:#横
    resize_im6 = im6.resize((int(im6_width * 0.55), int(im6_height * 0.55)))
    back_im.paste(resize_im6, (3870-int(im6_width*0.55/2), 1275-int(im6_height*0.55/2)))#右ページの中央にペースト 
back_im.save(os.path.join(output_dir_path, "0607.jpg"), quality=100, dpi=(300, 300))
#7-8ページ目ここまで


#9-10ページ目
back_im = base.copy()#共通
if im7_width < im7_height:#縦  
    resize_im7 = im7.resize((int(im7_width * 0.625), int(im7_height * 0.625)))
    back_im.paste(resize_im7, (1250-int(im7_width*0.625/2), 0))#左ページの中央にペースト 
else:#横
    resize_im7 = im7.resize((int(im7_width * 0.55), int(im7_height * 0.55)))
    back_im.paste(resize_im7, (1250-int(im7_width*0.55/2), 1180-int(im7_height*0.55/2)))#左ページの中央少し上寄りにペースト 
    back_im.paste(text2, (1410, 1930))#横文字の挿入

    
if im8_width < im8_height:#縦  
    resize_im8 = im8.resize((int(im8_width * 0.625), int(im8_height * 0.625)))
    back_im.paste(resize_im8, (3580-int(im8_width*0.55/2), 0))#右ページの中央にペースト 
    
else:#横
    resize_im8 = im8.resize((int(im8_width * 0.55), int(im8_height * 0.55)))
    back_im.paste(resize_im8, (3870-int(im8_width*0.55/2), 1275-int(im8_height*0.55/2)))#右ページの中央にペースト 
    
if  im8_width < im8_height and im7_width < im7_height:#左ページも右ページも縦写真だった場合（＝左ページへの横文字挿入が行われなかった場合）
    back_im.paste(rotare_text2, (4550, 1560))#90°回転させた横文字の挿入
    
    
back_im.save(os.path.join(output_dir_path, "0809.jpg"), quality=100, dpi=(300, 300))
#9-10ページ目ここまで




#11-12ページ目
back_im = base.copy()#共通
resize_im9 = im9.resize((int(im9_width * 0.6), int(im9_height * 0.6)))
back_im.paste(resize_im9, (1250-int(im9_width*0.6/2), 1275-int(im9_height*0.6/2)))#左ページの中央にペースト 

resize_im10 = im10.resize((int(im10_width * 0.6), int(im10_height * 0.6)))
back_im.paste(resize_im10, (3870-int(im10_width*0.6/2), 1265-int(im10_height*0.6/2)))#右ページの中央にペースト 

back_im.save(os.path.join(output_dir_path, "1011.jpg"), quality=100, dpi=(300, 300))
#3-4ページ目ここまで



#13-14ページ目
back_im = base.copy()#共通
if im11_width < im11_height:#縦  
    resize_im11 = im11.resize((int(im11_width * 0.7), int(im11_height * 0.7)))
    back_im.paste(resize_im11, (1250-int(im11_width*0.7/2), 1275-int(im11_height*0.7/2)))#左ページの中央にペースト 
    
else:#横
    resize_im11 = im11.resize((int(im11_width * 0.65), int(im11_height * 0.65)))
    back_im.paste(resize_im11, (1250-int(im11_width*0.6/2), 1275-int(im11_height*0.6/2)))#左ページの中央にペースト 

if im12_width < im12_height:#縦  
    resize_im12 = im12.resize((int(im12_width * 0.55), int(im12_height * 0.55)))
    back_im.paste(resize_im12, (3870-int(im12_width*0.55/2), 1275-int(im12_height*0.55/2)))#左ページの中央にペースト 
else:#横
    resize_im12 = im12.resize((int(im12_width * 0.55), int(im12_height * 0.55)))
    back_im.paste(resize_im12, (3870-int(im12_width*0.6/2), 1275-int(im12_height*0.6/2)))#右ページの中央にペースト 
back_im.save(os.path.join(output_dir_path, "01213.jpg"), quality=100, dpi=(300, 300))
#13-14ページ目ここまで


#15ページ目
back_im = base.copy()#共通
if im13_width < im13_height:#縦  
    resize_im13 = im13.resize((int(im13_width * 0.65), int(im13_height * 0.65)))
    back_im.paste(resize_im13, (1250-int(im13_width*0.55/2), 1275-int(im13_height*0.55/2)))#左ページの中央にペースト 
else:#横
    resize_im13= im13.resize((int(im13_width * 0.60), int(im13_height * 0.60)))
    back_im.paste(resize_im13, (3785-int(im13_width*0.6/2), 1275-int(im13_height*0.6/2)))#右ページの中央にペースト 
back_im.save(os.path.join(output_dir_path, "014.jpg"), quality=100, dpi=(300, 300))
#15ページ目ここまで


root.quit()#この処理のせいでエラーメッセージが出ますが、スルーしてOKです。
exit()#この処理のせいでエラーメッセージが出ますが、スルーしてOKです。
# Out:
# 表紙：/Users/user/Desktop/pic2/cover
# 中身：/Users/user/Desktop/pic/inside2
# ['20181214o03_1100647_002.jpg', '20181214o03_1100647_004.jpg', '20181214o03_1100647_006.jpg', '20181214o03_1100647_014.jpg', '20181214o03_1100647_017.jpg', '20181214o03_1100647_018.jpg', '20181214o03_1100647_027.jpg', '20181214o03_1100647_028.jpg', '20181214o03_1100647_032.jpg', '20181214o03_1100647_033.jpg', '20181214o03_1100647_034.jpg', '20181214o03_1100647_036.jpg', '20181214o03_1100647_038.jpg', '20181214o03_1100647_039.jpg', '20181214o03_1100647_041.jpg', 'cover.jpg']
# 出力先：/Users/user/Desktop/pic/output
# ERROR:root:Invalid alias: The name clear can't be aliased because it is another magic command.
# ERROR:root:Invalid alias: The name more can't be aliased because it is another magic command.
# ERROR:root:Invalid alias: The name less can't be aliased because it is another magic command.
# ERROR:root:Invalid alias: The name man can't be aliased because it is another magic command.

# %%
import os
import tkinter, tkinter.filedialog#[開く]で元画像フォルダー選択するために必要なライブラリ
from PIL import Image, ImageDraw, ImageFilter#画像処理に必要なライブラリ
from PIL import Image, ImageDraw, ImageFont#画像に文字を入れるために必要なライブラリ


base = Image.new('RGB', (500, 300), 'white')#下地の白画像をbaseという名前で生成


#元画像フォルダー選択
root = tkinter.Tk()
root.withdraw()
msg = '画像フォルダーを選択してください。'
img_dir_path = tkinter.filedialog.askdirectory(title=msg)
if (not img_dir_path): #[キャンセル]クリック時の処理
    print('フォルダーを選んでください。')
    sys.exit()
#元画像フォルダー選択ここまで

v_img_dir_path = os.path.join(img_dir_path, "tate")
h_img_dir_path = os.path.join(img_dir_path, "yoko")

#出力先フォルダー選択    
msg = '出力先フォルダーを選択してください。'    
output_dir_path = tkinter.filedialog.askdirectory(title=msg)    
if (not output_dir_path):#[キャンセル]クリック時の処理    
    print('フォルダーを選んでください。')
    sys.exit()
#出力先フォルダー選択ここまで


#表紙以外の写真をリスト化
print("縦写真："+ v_img_dir_path)
v_directory = os.listdir(v_img_dir_path)
v_directory.remove('.DS_Store')#Mac用
sorted_v_directory = sorted(v_directory )
print(sorted_v_directory)

print("横写真："+ h_img_dir_path)
h_directory = os.listdir(h_img_dir_path)
h_directory.remove('.DS_Store')#Mac用
sorted_h_directory = sorted(h_directory )
print(sorted_h_directory)

print("出力先："+ output_dir_path)

print(sorted_h_directory[3])



#ページ生成
back_im = base.copy()#共通

#１行目
back_im.paste(Image.open(os.path.join(h_img_dir_path,sorted_h_directory[0])), (0, 0))#ペースト 
back_im.paste(Image.open(os.path.join(h_img_dir_path,sorted_h_directory[1])), (200, 0))#ペースト 
back_im.paste(Image.open(os.path.join(v_img_dir_path,sorted_v_directory[0])), (400, 0))#ペースト 

#２行目
back_im.paste(Image.open(os.path.join(v_img_dir_path,sorted_v_directory[1])), (0, 100))#ペースト 
back_im.paste(Image.open(os.path.join(v_img_dir_path,sorted_v_directory[2])), (100, 100))#ペースト 
back_im.paste(Image.open(os.path.join(h_img_dir_path,sorted_h_directory[2])), (200, 100))#ペースト 
back_im.paste(Image.open(os.path.join(v_img_dir_path,sorted_v_directory[3])), (400, 100))#ペースト 

#3行目
back_im.paste(Image.open(os.path.join(h_img_dir_path,sorted_h_directory[3])), (0, 200))#ペースト 
back_im.paste(Image.open(os.path.join(v_img_dir_path,sorted_v_directory[4])), (200, 200))#ペースト 
back_im.paste(Image.open(os.path.join(h_img_dir_path,sorted_h_directory[4])), (300, 200))#ペースト 

back_im.save(os.path.join(output_dir_path, "0203.jpg"), quality=100, dpi=(300, 300))
#3-4ページ目ここまで



root.quit()#この処理のせいでエラーメッセージが出ますが、スルーしてOKです。
exit()#この処理のせいでエラーメッセージが出ますが、スルーしてOKです。
# Out:
# 縦写真：/Users/user/Desktop/pic/tate
# ['7aM.jpg', 'Tree_of_Hope.jpg', 'b23db06.jpg', 'ground.jpg', 'masaba.jpg']
# 横写真：/Users/user/Desktop/pic/yoko
# ['226677.jpg', 'down.jpg', 'download-1.jpg', 'download.jpg', 'tanken.jpg']
# 出力先：/Users/user/Desktop/pic
# download.jpg
# ERROR:root:Invalid alias: The name clear can't be aliased because it is another magic command.
# ERROR:root:Invalid alias: The name more can't be aliased because it is another magic command.
# ERROR:root:Invalid alias: The name less can't be aliased because it is another magic command.
# ERROR:root:Invalid alias: The name man can't be aliased because it is another magic command.

# %%
import os
import tkinter, tkinter.filedialog#[開く]で元画像フォルダー選択するために必要なライブラリ
from PIL import Image, ImageDraw, ImageFilter#画像処理に必要なライブラリ
from PIL import Image, ImageDraw, ImageFont#画像に文字を入れるために必要なライブラリ


base = Image.new('RGB', (500, 300), 'white')#下地の白画像をbaseという名前で生成


#元画像フォルダー選択
root = tkinter.Tk()
root.withdraw()
msg = '画像フォルダーを選択してください。'
img_dir_path = tkinter.filedialog.askdirectory(title=msg)
if (not img_dir_path): #[キャンセル]クリック時の処理
    print('フォルダーを選んでください。')
    sys.exit()
#元画像フォルダー選択ここまで

v_img_dir_path = os.path.join(img_dir_path, "tate")
h_img_dir_path = os.path.join(img_dir_path, "yoko")

#出力先フォルダー選択    
msg = '出力先フォルダーを選択してください。'    
output_dir_path = tkinter.filedialog.askdirectory(title=msg)    
if (not output_dir_path):#[キャンセル]クリック時の処理    
    print('フォルダーを選んでください。')
    sys.exit()
#出力先フォルダー選択ここまで


#表紙以外の写真をリスト化
print("縦写真："+ v_img_dir_path)
v_directory = os.listdir(v_img_dir_path)
v_directory.remove('.DS_Store')#Mac用
sorted_v_directory = sorted(v_directory )
print(sorted_v_directory)

print("横写真："+ h_img_dir_path)
h_directory = os.listdir(h_img_dir_path)
h_directory.remove('.DS_Store')#Mac用
sorted_h_directory = sorted(h_directory )
print(sorted_h_directory)

print("出力先："+ output_dir_path)

#ページ生成
back_im = base.copy()#共通
i = 0

while i < len(sorted_h_directory) or (sorted_v_directory):

#１行目
    back_im.paste(Image.open(os.path.join(h_img_dir_path,sorted_h_directory[i])), (0, 0))#ペースト 
    back_im.paste(Image.open(os.path.join(h_img_dir_path,sorted_h_directory[i+1])), (200, 0))#ペースト 
    back_im.paste(Image.open(os.path.join(v_img_dir_path,sorted_v_directory[i])), (400, 0))#ペースト 

#２行目
    back_im.paste(Image.open(os.path.join(v_img_dir_path,sorted_v_directory[i+1])), (0, 100))#ペースト 
    back_im.paste(Image.open(os.path.join(v_img_dir_path,sorted_v_directory[i+2])), (100, 100))#ペースト 
    back_im.paste(Image.open(os.path.join(h_img_dir_path,sorted_h_directory[i+2])), (200, 100))#ペースト 
    back_im.paste(Image.open(os.path.join(v_img_dir_path,sorted_v_directory[i+3])), (400, 100))#ペースト 

#3行目
    back_im.paste(Image.open(os.path.join(h_img_dir_path,sorted_h_directory[i+3])), (0, 200))#ペースト 
    back_im.paste(Image.open(os.path.join(v_img_dir_path,sorted_v_directory[i+4])), (200, 200))#ペースト 
    back_im.paste(Image.open(os.path.join(h_img_dir_path,sorted_h_directory[i+4])), (300, 200))#ペースト 

    back_im.save(os.path.join(output_dir_path,   str(i)+"0203.jpg"), quality=100, dpi=(300, 300))
    
    i = i +5#縦５枚横５枚の写真が使われているため
#ページ生成ここまで



root.quit()#この処理のせいでエラーメッセージが出ますが、スルーしてOKです。
exit()#この処理のせいでエラーメッセージが出ますが、スルーしてOKです。
# Out:
# 縦写真：/Users/user/Desktop/test/4444/tate
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-9b9d724f3dc2> in <module>
#      32 #表紙以外の写真をリスト化
#      33 print("縦写真："+ v_img_dir_path)
# ---> 34 v_directory = os.listdir(v_img_dir_path)
#      35 v_directory.remove('.DS_Store')#Mac用
#      36 sorted_v_directory = sorted(v_directory )
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/user/Desktop/test/4444/tate'
