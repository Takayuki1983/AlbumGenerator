# %%
import os
import tkinter, tkinter.filedialog#[開く]で元画像フォルダー選択するために必要なライブラリ
from PIL import Image, ImageDraw, ImageFilter#画像処理に必要なライブラリ

cov_base_tate = Image.open('base_tate.jpg')#表紙の下地画像を呼び出し
cov_base_yoko = Image.open('base_yoko.jpg')#表紙の下地画像を呼び出し
base = Image.new('RGB', (5043, 2551), 'white')#下地の白画像をbaseという名前で生成

#表紙元画像フォルダー選択
root = tkinter.Tk()
root.withdraw()
msg = '画像フォルダーを選択してください。'
img_dir_path = tkinter.filedialog.askdirectory(title=msg)
if (not img_dir_path): #[キャンセル]クリック時の処理
    print('フォルダーを選んでください。')
    sys.exit()
#表紙元画像フォルダー選択ここまで

folder_list = os.listdir(img_dir_path)#フォルダ名のリストを作成
print("対象フォルダ")
print(folder_list)

i = 0

while i < len(folder_list) :

#表紙のディレクトリ
#print("表紙："+ cover_img_dir_path)
    cover_path = os.path.join(img_dir_path,folder_list[i],"cover")
    other_path = os.path.join(img_dir_path,folder_list[i],"other")
    print("表紙："+ cover_path)
    cover_directory = os.listdir(cover_path)
#cover_directory.remove('.DS_Store')#Mac用
    print(cover_directory)
    print()
    directory = os.listdir(other_path)
#directory.remove('.DS_Store')#Mac用
    sorted_directory = sorted(directory )
    print("中身："+ other_path)
    print(sorted_directory)
    print()
    print("出力先："+ folder_list[i])

    cov = Image.open(os.path.join(img_dir_path,folder_list[i],"cover",cover_directory[0]))
    cov_width, cov_height = cov.size
    im0 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[0]))
    im0_width, im0_height = im0.size
    im1 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[1]))
    im1_width, im1_height = im1.size
    im2 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[2]))
    im2_width, im2_height = im2.size
    im3 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[3]))
    im3_width, im3_height = im3.size
    im4 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[4]))
    im4_width, im4_height = im4.size
    im5 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[5]))
    im5_width, im5_height = im5.size
    im6 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[6]))
    im6_width, im6_height = im6.size
    im7 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[7]))
    im7_width, im7_height = im7.size
    im8 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[8]))
    im8_width, im8_height = im8.size
    im9 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[9]))
    im9_width, im9_height = im9.size
    im10 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[10]))
    im10_width, im10_height = im10.size
    im11 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[11]))
    im11_width, im11_height = im11.size
    im12 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[12]))
    im12_width, im12_height = im12.size
    im13 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[13]))
    im13_width, im13_height = im13.size

#表紙
    back_im = base.copy()#共通
    back_im_tate = cov_base_tate.copy()
    back_im_yoko = cov_base_yoko.copy()
    resize_cov = cov.resize((int(cov_width * 0.73), int(cov_height * 0.73)))

    if cov_width < cov_height:
        if  6800-10 < int(cov_width) + int(cov_height)  < 6800 + 10 and 290 < cov.info['dpi'][0] < 360:#縦横のピクセルが規定値±5の場合またはdpiが290～360の間
            back_im_tate.paste(resize_cov, (4975, 325))#縦
            back_im_tate.save(os.path.join(img_dir_path,folder_list[i], "0000.jpg"), quality=100, dpi=(300, 300))
        else:
            back_im_tate.paste(resize_cov, (4975, 325))#縦
            back_im_tate.save(os.path.join(img_dir_path,folder_list[i], "0000【エラー】.jpg"), quality=100, dpi=(400, 400))

    else:
        if  6800-10 <int(cov_width) + int(cov_height)  < 6800 + 10 and 290 < cov.info['dpi'][0] <360:#縦横のピクセルが規定値±5の場合またはdpiが290～360の間
            back_im_yoko.paste(resize_cov, (4025, 1140))#横
            back_im_yoko.save(os.path.join(img_dir_path,folder_list[i], "0000.jpg"), quality=100, dpi=(300, 300))
        else:
            back_im_yoko.paste(resize_cov, (4025, 1140))#横
            back_im_yoko.save(os.path.join(img_dir_path,folder_list[i], "0000【エラー】.jpg"), quality=100, dpi=(400, 400))
#表紙ここまで       
 
    
#1-2ページ目
    back_im = base.copy()#共通
    if im0_width < im0_height:#縦  
        resize_im0 = im0.resize((int(im0_width * 0.584), int(im0_height * 0.584)))
        back_im.paste(resize_im0, (3873-int(im0_width*0.584/2), 1275-int(im0_height*0.584/2)))#左ページの中央にペースト 
    else:#横
        resize_im0 = im0.resize((int(im0_width * 0.614), int(im0_height * 0.614)))
        back_im.paste(resize_im0, (3873-int(im0_width*0.614/2), 1275-int(im0_height*0.614/2)))#左ページの中央にペースト 
    
    if 6800-60 <int(im0_width) + int(im0_height) < 6800 + 60 and 290 < im0.info['dpi'][0] <360:#縦横のピクセルが規定値±30の場合またはdpiが290～360の間
        back_im.save(os.path.join(img_dir_path,folder_list[i], "0001.jpg"), quality=100, dpi=(300, 300))
    else:
        back_im.save(os.path.join(img_dir_path,folder_list[i], "0001【エラー】.jpg"), quality=100, dpi=(300, 300))
    
        
#1-2ページ目ここまで



#３-４ページ目
    back_im = base.copy()#共通
    if im1_width < im1_height:#縦  
        resize_im1 = im1.resize((int(im1_width * 0.584), int(im1_height * 0.584)))
        back_im.paste(resize_im1, (1259-int(im1_width*0.584/2), 1275-int(im1_height*0.584/2)))#左ページの中央にペースト 
    else:#横
        resize_im1 = im1.resize((int(im1_width * 0.614), int(im1_height * 0.614)))
        back_im.paste(resize_im1, (1259-int(im1_width*0.614/2), 1275-int(im1_height*0.614/2)))#左ページの中央にペースト 
    
    if im2_width < im2_height:#縦  
        resize_im2 = im2.resize((int(im2_width * 0.584), int(im2_height * 0.584)))
        back_im.paste(resize_im2, (3873-int(im2_width*0.584/2), 1275-int(im2_height*0.584/2)))#右ページの中央にペースト 
    else:#横
        resize_im2 = im2.resize((int(im2_width * 0.614), int(im2_height * 0.614)))
        back_im.paste(resize_im2, (3873-int(im2_width*0.614/2), 1275-int(im2_height*0.614/2)))#右ページの中央にペースト 
    
    if 6800*2-60*2 <int(im1_width) + int(im1_height) + int(im2_width) + int(im2_height)  < 6800*2 + 60*2 and 290 < im1.info['dpi'][0] <360 and  290 < im2.info['dpi'][0] <360:#縦横のピクセルが規定値±30の場合またはdpiが290～360の間
        back_im.save(os.path.join(img_dir_path,folder_list[i], "0203.jpg"), quality=100, dpi=(300, 300))
    else:
        back_im.save(os.path.join(img_dir_path,folder_list[i], "0203【エラー】.jpg"), quality=100, dpi=(300, 300))

#３-４ページ目ここまで    


#５-６ページ目
    back_im = base.copy()#共通
    if im3_width < im3_height:#縦  
        resize_im3 = im3.resize((int(im3_width * 0.584), int(im3_height * 0.584)))
        back_im.paste(resize_im3, (1259-int(im3_width*0.584/2), 1275-int(im3_height*0.584/2)))#左ページの中央にペースト 
    else:#横
        resize_im3 = im3.resize((int(im3_width * 0.614), int(im3_height * 0.614)))
        back_im.paste(resize_im3, (1259-int(im3_width*0.614/2), 1275-int(im3_height*0.614/2)))#左ページの中央にペースト 
    
    if im4_width < im4_height:#縦  
        resize_im4 = im4.resize((int(im4_width * 0.584), int(im4_height * 0.584)))
        back_im.paste(resize_im4, (3873-int(im4_width*0.584/2), 1275-int(im4_height*0.584/2)))#右ページの中央にペースト 
    else:#横
        resize_im4 = im4.resize((int(im4_width * 0.614), int(im4_height * 0.614)))
        back_im.paste(resize_im4, (3873-int(im4_width*0.614/2), 1275-int(im4_height*0.614/2)))#右ページの中央にペースト 
    
    if 6800*2-60*2 <int(im3_width) + int(im3_height) + int(im4_width) + int(im4_height)  < 6800*2 + 60*2 and 290 < im3.info['dpi'][0] <360 and  290 < im4.info['dpi'][0] <360:#縦横のピクセルが規定値±30の場合またはdpiが290～360の間
        back_im.save(os.path.join(img_dir_path,folder_list[i], "0405.jpg"), quality=100, dpi=(300, 300))
    else:
        back_im.save(os.path.join(img_dir_path,folder_list[i], "0405【エラー】.jpg"), quality=100, dpi=(300, 300))
#５-６ページ目ここまで


#７-８ページ目
    back_im = base.copy()#共通
    if im5_width < im5_height:#縦  
        resize_im5 = im5.resize((int(im5_width * 0.584), int(im5_height * 0.584)))
        back_im.paste(resize_im5, (1259-int(im5_width*0.584/2), 1275-int(im5_height*0.584/2)))#左ページの中央にペースト 
    else:#横
        resize_im5 = im5.resize((int(im5_width * 0.614), int(im5_height * 0.614)))
        back_im.paste(resize_im5, (1259-int(im5_width*0.614/2), 1275-int(im5_height*0.614/2)))#左ページの中央にペースト 
    
    if im6_width < im6_height:#縦  
        resize_im6 = im6.resize((int(im6_width * 0.584), int(im6_height * 0.584)))
        back_im.paste(resize_im6, (3873-int(im6_width*0.584/2), 1275-int(im6_height*0.584/2)))#右ページの中央にペースト 
    else:#横
        resize_im6 = im6.resize((int(im6_width * 0.614), int(im6_height * 0.614)))
        back_im.paste(resize_im6, (3873-int(im6_width*0.614/2), 1275-int(im6_height*0.614/2)))#右ページの中央にペースト 
    
    if 6800*2-60*2 <int(im5_width) + int(im5_height) + int(im6_width) + int(im6_height)  < 6800*2 + 60*2 and 290 < im5.info['dpi'][0] <360 and  290 < im6.info['dpi'][0] <360:#縦横のピクセルが規定値±30の場合またはdpiが290～360の間
        back_im.save(os.path.join(img_dir_path,folder_list[i], "0607.jpg"), quality=100, dpi=(300, 300))
    else:
        back_im.save(os.path.join(img_dir_path,folder_list[i], "0607【エラー】.jpg"), quality=100, dpi=(300, 300))
#７-８ページ目ここまで


#９-１０ページ目
    back_im = base.copy()#共通
    if im7_width < im7_height:#縦  
        resize_im7 = im7.resize((int(im7_width * 0.584), int(im7_height * 0.584)))
        back_im.paste(resize_im7, (1259-int(im7_width*0.584/2), 1275-int(im7_height*0.584/2)))#左ページの中央にペースト 
    else:#横
        resize_im7 = im7.resize((int(im7_width * 0.614), int(im7_height * 0.614)))
        back_im.paste(resize_im7, (1259-int(im7_width*0.614/2), 1275-int(im7_height*0.614/2)))#左ページの中央にペースト 
    
    if im8_width < im8_height:#縦  
        resize_im8 = im8.resize((int(im8_width * 0.584), int(im8_height * 0.584)))
        back_im.paste(resize_im8, (3873-int(im8_width*0.584/2), 1275-int(im8_height*0.584/2)))#右ページの中央にペースト 
    else:#横
        resize_im8 = im8.resize((int(im8_width * 0.614), int(im8_height * 0.614)))
        back_im.paste(resize_im8, (3873-int(im8_width*0.614/2), 1275-int(im8_height*0.614/2)))#右ページの中央にペースト 
    
    if 6800*2-60*2 <int(im7_width) + int(im7_height) + int(im8_width) + int(im8_height)  < 6800*2 + 60*2 and 290 < im7.info['dpi'][0] <360 and  290 < im8.info['dpi'][0] <360:#縦横のピクセルが規定値±30の場合またはdpiが290～360の間
        back_im.save(os.path.join(img_dir_path,folder_list[i], "0809.jpg"), quality=100, dpi=(300, 300))
    else:
        back_im.save(os.path.join(img_dir_path,folder_list[i], "0809【エラー】.jpg"), quality=100, dpi=(300, 300))
#９-１０ページ目ここまで


#１１-１２ページ目
    back_im = base.copy()#共通
    if im9_width < im9_height:#縦  
        resize_im9 = im9.resize((int(im9_width * 0.584), int(im9_height * 0.584)))
        back_im.paste(resize_im9, (1259-int(im9_width*0.584/2), 1275-int(im9_height*0.584/2)))#左ページの中央にペースト 
    else:#横
        resize_im9 = im9.resize((int(im9_width * 0.614), int(im9_height * 0.614)))
        back_im.paste(resize_im9, (1259-int(im9_width*0.614/2), 1275-int(im9_height*0.614/2)))#左ページの中央にペースト 
    
    if im10_width < im10_height:#縦  
        resize_im10 = im10.resize((int(im10_width * 0.584), int(im10_height * 0.584)))
        back_im.paste(resize_im10, (3873-int(im10_width*0.584/2), 1275-int(im10_height*0.584/2)))#右ページの中央にペースト 
    else:#横
        resize_im10 = im10.resize((int(im10_width * 0.614), int(im10_height * 0.614)))
        back_im.paste(resize_im10, (3873-int(im10_width*0.614/2), 1275-int(im10_height*0.614/2)))#右ページの中央にペースト 
    
    if 6800*2-60*2 <int(im9_width) + int(im9_height) + int(im10_width) + int(im10_height)  < 6800*2 + 60*2 and 290 < im9.info['dpi'][0] <360 and  290 < im10.info['dpi'][0] <360:#縦横のピクセルが規定値±30の場合またはdpiが290～360の間
        back_im.save(os.path.join(img_dir_path,folder_list[i], "1011.jpg"), quality=100, dpi=(300, 300))
    else:
        back_im.save(os.path.join(img_dir_path,folder_list[i], "1011【エラー】.jpg"), quality=100, dpi=(300, 300))
#１１-１２ページ目ここまで


#１２-１３ページ目
    back_im = base.copy()#共通
    if im11_width < im11_height:#縦  
        resize_im11 = im11.resize((int(im11_width * 0.584), int(im11_height * 0.584)))
        back_im.paste(resize_im11, (1259-int(im11_width*0.584/2), 1275-int(im11_height*0.584/2)))#左ページの中央にペースト 
    else:#横
        resize_im11 = im11.resize((int(im11_width * 0.614), int(im11_height * 0.614)))
        back_im.paste(resize_im11, (1259-int(im11_width*0.614/2), 1275-int(im11_height*0.614/2)))#左ページの中央にペースト 
    
    if im12_width < im12_height:#縦  
        resize_im12 = im12.resize((int(im12_width * 0.584), int(im12_height * 0.584)))
        back_im.paste(resize_im12, (3873-int(im12_width*0.584/2), 1275-int(im12_height*0.584/2)))#右ページの中央にペースト 
    else:#横
        resize_im12 = im12.resize((int(im12_width * 0.614), int(im12_height * 0.614)))
        back_im.paste(resize_im12, (3873-int(im12_width*0.614/2), 1275-int(im12_height*0.614/2)))#右ページの中央にペースト 
    
    if 6800*2-60*2 <int(im11_width) + int(im11_height) + int(im12_width) + int(im12_height)  < 6800*2 + 60*2 and 290 < im11.info['dpi'][0] <360 and  290 < im12.info['dpi'][0] <360:#縦横のピクセルが規定値±30の場合またはdpiが290～360の間
        back_im.save(os.path.join(img_dir_path,folder_list[i], "1213.jpg"), quality=100, dpi=(300, 300))
    else:
        back_im.save(os.path.join(img_dir_path,folder_list[i], "1213【エラー】.jpg"), quality=100, dpi=(300, 300))
#１２-１３ページ目ここまで


#15ページ目
    back_im = base.copy()#共通
    if im13_width < im13_height:#縦  
        resize_im13 = im13.resize((int(im13_width * 0.584), int(im13_height * 0.584)))
        back_im.paste(resize_im13, (1259-int(im13_width*0.584/2), 1275-int(im13_height*0.584/2)))#左ページの中央にペースト 
    else:#横
        resize_im13 = im13.resize((int(im13_width * 0.614), int(im13_height * 0.614)))
        back_im.paste(resize_im13, (1259-int(im13_width*0.614/2), 1275-int(im13_height*0.614/2)))#左ページの中央にペースト 
   
    if 6800-60 <int(im13_width) + int(im13_height) < 6800 + 60 and 290 < im13.info['dpi'][0] <360:#縦横のピクセルが規定値±30の場合またはdpiが290～360の間
        back_im.save(os.path.join(img_dir_path,folder_list[i], "1400.jpg"), quality=100, dpi=(300, 300))
    else:
        back_im.save(os.path.join(img_dir_path,folder_list[i], "1400【エラー】.jpg"), quality=100, dpi=(300, 300))
#15ページ目ここまで


    i = i + 1 #画像の行数によって値を変えてください

root.quit()#この処理のせいでエラーメッセージが出ますが、スルーしてOKです。
exit()#この処理のせいでエラーメッセージが出ますが、スルーしてOKです。
# Out:
# 対象フォルダ
# ['1126017_自動化テスト', '1126325_20191015os032802426_541738_15', '1126328_20191015oa062842890_541886_15', '1309553_20191015oc052783674_541830_15', '1309756_20191015oc042776022_541782_15']
# 表紙：C:/Users/moriya/Desktop/0000\1126017_自動化テスト\cover
# ['20190915o09_1126017_015.jpg']
#
# 中身：C:/Users/moriya/Desktop/0000\1126017_自動化テスト\other
# ['20190915o09_1126017_000.jpg', '20190915o09_1126017_001.jpg', '20190915o09_1126017_002.jpg', '20190915o09_1126017_004.jpg', '20190915o09_1126017_005.jpg', '20190915o09_1126017_007.jpg', '20190915o09_1126017_008.jpg', '20190915o09_1126017_010.jpg', '20190915o09_1126017_011.jpg', '20190915o09_1126017_012.jpg', '20190915o09_1126017_012_2.jpg', '20190915o09_1126017_013.jpg', '20190915o09_1126017_019.jpg', '20190915o09_1126017_020.jpg', '20190915o09_1126017_030.jpg']
#
# 出力先：1126017_自動化テスト
# 表紙：C:/Users/moriya/Desktop/0000\1126325_20191015os032802426_541738_15\cover
# ['20191015o03_1126325_011.jpg']
#
# ...
